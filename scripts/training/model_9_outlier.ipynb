# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import os

# %%
import xgboost as xgb

# %%
xgb.__version__
# Out:
# '1.1.1'

# %%
DATA_DIR_PATH = os.path.join('..', '..', 'data')

def laod_data(file_name):
  file_path = os.path.join(DATA_DIR_PATH, file_name)
  return pd.read_csv(file_path, header=0)

# %%
df_train = laod_data('bookmark_train_data.csv')
print(len(df_train))
#df_train.head(3)
# Out:
# 199

# %%
from sklearn.preprocessing import LabelEncoder

cat_le = LabelEncoder()
cat_le.fit(df_train['category'])

WORD_CLASSE_LABELS = ['その他', 'フィラー', '副詞', '助動詞', '助詞',
                     '動詞', '名詞', '形容詞', '感動詞', '接続詞',
                     '接頭詞', '記号', '連体詞',]
new_wc_columns = {}
for (i, name) in enumerate(WORD_CLASSE_LABELS):
  new_wc_columns['wc_sum_{}'.format(name)] = 'wc_sum_{}'.format(i)
  new_wc_columns['wc_rate_{}'.format(name)] = 'wc_rate_{}'.format(i)


def data_preprocess(df):
  new_df = df.drop(['ncode', 'title', 'bookmark_cat'], axis=1)

  new_df['category'] = cat_le.transform(new_df['category'])

  new_df['rating'] = new_df['rating'] * 10
  new_df = new_df.astype({'rating': 'int32'})

  #wc_columns = [col for col in new_df.columns if col.find('wc_') != -1]
  #new_df = new_df.drop(wc_columns, axis=1)
  wc_columns = [col for col in new_df.columns if col.find('wc_sum_') != -1]
  new_df = new_df.drop(wc_columns, axis=1)
  new_df = new_df.rename(columns=new_wc_columns)

  kw_columns = [col for col in new_df.columns if col.find('kw_') != -1]
  new_df = new_df.drop(kw_columns, axis=1)

  return new_df

# %%
df_train.keys()
# Out:
# Index(['ncode', 'title', 'category', 'bookmark_cat', 'created_at',
#        'updated_at', 'char_count_sum', 'new_line_count_sum',
#        'talk_char_count_sum', 'new_line_count_rate_sum',
#        'talk_char_count_rate_sum', 'char_count_avg', 'new_line_count_avg',
#        'talk_char_count_avg', 'new_line_count_rate_avg',
#        'talk_char_count_rate_avg', 'wc_sum_その他', 'wc_sum_フィラー', 'wc_sum_副詞',
#        'wc_sum_助動詞', 'wc_sum_助詞', 'wc_sum_動詞', 'wc_sum_名詞', 'wc_sum_形容詞',
#        'wc_sum_感動詞', 'wc_sum_接続詞', 'wc_sum_接頭詞', 'wc_sum_記号', 'wc_sum_連体詞',
#        'wc_rate_その他', 'wc_rate_フィラー', 'wc_rate_副詞', 'wc_rate_助動詞',
#        'wc_rate_助詞', 'wc_rate_動詞', 'wc_rate_名詞', 'wc_rate_形容詞', 'wc_rate_感動詞',
#        'wc_rate_接続詞', 'wc_rate_接頭詞', 'wc_rate_記号', 'wc_rate_連体詞', 'kw_冒険者',
#        'kw_魔王', 'kw_日常', 'kw_成り上がり', 'kw_内政', 'kw_恋愛', 'kw_無双', 'kw_青春',
#        'kw_ハーレム', 'kw_男主人公', 'kw_奴隷', 'kw_テンプレ', 'kw_勘違い', 'kw_ほのぼの', 'kw_貴族',
#        'kw_ギルド', 'kw_コメディ', 'kw_異世界', 'kw_エルフ', 'kw_ファンタジー', 'kw_オリジナル戦記',
#        'kw_チート', 'kw_R15', 'kw_ダンジョン', 'kw_ステータス', 'kw_料理', 'kw_ラブコメ', 'kw_中世',
#        'kw_異世界召喚', 'kw_剣と魔法', 'kw_学園', 'kw_異能力バトル', 'kw_勇者', 'kw_冒険',
#        'kw_主人公最強', 'kw_転生', 'kw_シリアス', 'kw_異世界転移', 'kw_追放', 'kw_ざまぁ', 'kw_西洋',
#        'kw_最強', 'kw_スキル', 'kw_魔法', 'kw_異世界転生', 'kw_ご都合主義', 'kw_ハッピーエンド',
#        'kw_書籍化', 'kw_おっさん', 'kw_残酷な描写あり', 'rating'],
#       dtype='object')

# %%
df_train2 = data_preprocess(df_train)
df_train2.head(3)
# Out:
#    category    created_at    updated_at  char_count_sum  new_line_count_sum  \
# 0         6  1.586338e+09  1.593468e+09           92340                3840
# 1         6  1.590714e+09  1.593338e+09           77880                4140
# 2         6  1.575176e+09  1.593429e+09           59880                3090
#
#    talk_char_count_sum  new_line_count_rate_sum  talk_char_count_rate_sum  \
# 0                28950                 0.041585                  0.313515
# 1                 4950                 0.053159                  0.063559
# 2                10230                 0.051603                  0.170842
#
#    char_count_avg  new_line_count_avg  ...  wc_rate_4  wc_rate_5  wc_rate_6  \
# 0          3078.0               128.0  ...   0.237664   0.226083   0.225076
# 1          2596.0               138.0  ...   0.238590   0.238013   0.217215
# 2          1996.0               103.0  ...   0.240486   0.177328   0.285020
#
#    wc_rate_7  wc_rate_8  wc_rate_9  wc_rate_10  wc_rate_11  wc_rate_12  rating
# 0   0.013595   0.006042   0.007049    0.006042    0.144008    0.011078      30
# 1   0.017909   0.001155   0.010399    0.001155    0.138070    0.013287      40
# 2   0.014575   0.000000   0.005668    0.008907    0.148178    0.005668      30
#
# [3 rows x 27 columns]

# %%
feature_names = df_train2.keys()[:-1]

# %%
print(feature_names)
print(len(feature_names))
# Out:
# Index(['category', 'created_at', 'updated_at', 'char_count_sum',
#        'new_line_count_sum', 'talk_char_count_sum', 'new_line_count_rate_sum',
#        'talk_char_count_rate_sum', 'char_count_avg', 'new_line_count_avg',
#        'talk_char_count_avg', 'new_line_count_rate_avg',
#        'talk_char_count_rate_avg', 'wc_rate_0', 'wc_rate_1', 'wc_rate_2',
#        'wc_rate_3', 'wc_rate_4', 'wc_rate_5', 'wc_rate_6', 'wc_rate_7',
#        'wc_rate_8', 'wc_rate_9', 'wc_rate_10', 'wc_rate_11', 'wc_rate_12'],
#       dtype='object')
# 26

# %%
def filter_outlier(df_input, col):
  mean = df_input.mean()
  sigma = df_input.std() 

  low = mean[col] - 3 * sigma[col]
  high = mean[col] + 3 * sigma[col]

  df_3sigma = df_input[(df_train2[col] > low) & (df_train2[col] < high)]

  return df_3sigma

# %%
import warnings
warnings.filterwarnings('ignore')

# %%
print(df_train2.keys()[3:-1])
# Out:
# Index(['char_count_sum', 'new_line_count_sum', 'talk_char_count_sum',
#        'new_line_count_rate_sum', 'talk_char_count_rate_sum', 'char_count_avg',
#        'new_line_count_avg', 'talk_char_count_avg', 'new_line_count_rate_avg',
#        'talk_char_count_rate_avg', 'wc_rate_0', 'wc_rate_1', 'wc_rate_2',
#        'wc_rate_3', 'wc_rate_4', 'wc_rate_5', 'wc_rate_6', 'wc_rate_7',
#        'wc_rate_8', 'wc_rate_9', 'wc_rate_10', 'wc_rate_11', 'wc_rate_12'],
#       dtype='object')

# %%
df_train3 = df_train2.copy()

for col in df_train3.keys()[3:-1]:
  df_train3 = filter_outlier(df_train3, col)

# %%
df_train3
# Out:
#      category    created_at    updated_at  char_count_sum  new_line_count_sum  \
# 0           6  1.586338e+09  1.593468e+09           92340                3840
# 1           6  1.590714e+09  1.593338e+09           77880                4140
# 4           6  1.589543e+09  1.593688e+09          100920                3000
# 6           6  1.572513e+09  1.593421e+09           78840                4620
# 7           6  1.584934e+09  1.593508e+09           51300                1980
# ..        ...           ...           ...             ...                 ...
# 193         8  1.421669e+09  1.517615e+09          187440                8130
# 194         6  1.436805e+09  1.574938e+09          122640                5640
# 196         6  1.474528e+09  1.545340e+09           97380                4440
# 197         6  1.470146e+09  1.526466e+09           99570                8070
# 198         8  1.496460e+09  1.537873e+09           77580                2970
#
#      talk_char_count_sum  new_line_count_rate_sum  talk_char_count_rate_sum  \
# 0                  28950                 0.041585                  0.313515
# 1                   4950                 0.053159                  0.063559
# 4                  34290                 0.029727                  0.339774
# 6                   1410                 0.058600                  0.017884
# 7                   3450                 0.038596                  0.067251
# ..                   ...                      ...                       ...
# 193                36720                 0.043374                  0.195903
# 194                 8130                 0.045988                  0.066292
# 196                 4800                 0.045595                  0.049291
# 197                10650                 0.081049                  0.106960
# 198                 9930                 0.038283                  0.127997
#
#      char_count_avg  new_line_count_avg  ...  wc_rate_4  wc_rate_5  wc_rate_6  \
# 0            3078.0               128.0  ...   0.237664   0.226083   0.225076
# 1            2596.0               138.0  ...   0.238590   0.238013   0.217215
# 4            3364.0               100.0  ...   0.264463   0.205307   0.279252
# 6            2628.0               154.0  ...   0.245772   0.245209   0.227170
# 7            1710.0                66.0  ...   0.242481   0.217105   0.250000
# ..              ...                 ...  ...        ...        ...        ...
# 193          6248.0               271.0  ...   0.256209   0.204328   0.229162
# 194          4088.0               188.0  ...   0.251648   0.210547   0.269097
# 196          3246.0               148.0  ...   0.246251   0.208515   0.265119
# 197          3319.0               269.0  ...   0.246718   0.204595   0.274070
# 198          2586.0                99.0  ...   0.240986   0.204928   0.233173
#
#      wc_rate_7  wc_rate_8  wc_rate_9  wc_rate_10  wc_rate_11  wc_rate_12  \
# 0     0.013595   0.006042   0.007049    0.006042    0.144008    0.011078
# 1     0.017909   0.001155   0.010399    0.001155    0.138070    0.013287
# 4     0.015224   0.001305   0.008264    0.001305    0.098304    0.011309
# 6     0.010710   0.001691   0.004510    0.000000    0.114994    0.007328
# 7     0.015977   0.001880   0.008459    0.001880    0.139098    0.004699
# ..         ...        ...        ...         ...         ...         ...
# 193   0.020900   0.006147   0.005164    0.001475    0.146054    0.007131
# 194   0.014734   0.003490   0.006592    0.002714    0.119814    0.009306
# 196   0.015481   0.000000   0.011611    0.001451    0.124819    0.008708
# 197   0.009847   0.002735   0.007112    0.000547    0.142232    0.004376
# 198   0.012019   0.003606   0.006611    0.000601    0.155048    0.008413
#
#      rating
# 0        30
# 1        40
# 4        30
# 6        30
# 7        40
# ..      ...
# 193      15
# 194      10
# 196      15
# 197      10
# 198      15
#
# [151 rows x 27 columns]

# %%
#X = df_train2.drop(['rating'], axis=1).values
#y = df_train2['rating'].values
X = df_train3.drop(['rating'], axis=1).values
y = df_train3['rating'].values

print(X.shape, y.shape)
# Out:
# (151, 26) (151,)

# %%
# print(y)

# u, counts = np.unique(y, return_counts=True)
# print(len(u))
# print(u)
# print(counts)

# %%
from imblearn.over_sampling import RandomOverSampler

# %%
ros = RandomOverSampler(random_state=0)
X_resampled, y_resampled = ros.fit_resample(X, y)
print(X_resampled.shape, y_resampled.shape)

u, counts = np.unique(y_resampled, return_counts=True)
print(len(u))
print(u)
print(counts)
# Out:
# (750, 26) (750,)
# 15
# [ 5 10 15 17 20 25 30 35 40 45 50 52 60 67 75]
# [50 50 50 50 50 50 50 50 50 50 50 50 50 50 50]

# %%
from sklearn.model_selection import train_test_split

#X_train, X_val, y_train, y_val = train_test_split(X, y, test_size=0.3, shuffle=True, random_state=1)
X_train, X_val, y_train, y_val = train_test_split(X_resampled, y_resampled, test_size=0.3, shuffle=True, random_state=1)

# %%
print(X_train.shape, y_train.shape)
print(X_val.shape, y_val.shape)
# Out:
# (525, 26) (525,)
# (225, 26) (225,)

# %%
dtrain = xgb.DMatrix(X_train, label=y_train, feature_names=feature_names)
dval = xgb.DMatrix(X_val, label=y_val, feature_names=feature_names)

# %%
print(dtrain.feature_names)
# Out:
# ['category', 'created_at', 'updated_at', 'char_count_sum', 'new_line_count_sum', 'talk_char_count_sum', 'new_line_count_rate_sum', 'talk_char_count_rate_sum', 'char_count_avg', 'new_line_count_avg', 'talk_char_count_avg', 'new_line_count_rate_avg', 'talk_char_count_rate_avg', 'wc_rate_0', 'wc_rate_1', 'wc_rate_2', 'wc_rate_3', 'wc_rate_4', 'wc_rate_5', 'wc_rate_6', 'wc_rate_7', 'wc_rate_8', 'wc_rate_9', 'wc_rate_10', 'wc_rate_11', 'wc_rate_12']

# %%
xgb_params = {
    'objective': 'reg:linear',
    'eval_metric': 'rmse',
}

evals = [(dtrain, 'train'), (dval, 'eval')]
evals_result = {}

bst = xgb.train(xgb_params,
                dtrain,
                num_boost_round=100,
                early_stopping_rounds=20,
                evals=evals,
                evals_result=evals_result)
# Out:
# [02:06:09] WARNING: /Users/travis/build/dmlc/xgboost/src/objective/regression_obj.cu:170: reg:linear is now deprecated in favor of reg:squarederror.
# [0]	train-rmse:30.03583	eval-rmse:29.75313
# Multiple eval metrics have been passed: 'eval-rmse' will be used for early stopping.
#
# Will train until eval-rmse hasn't improved in 20 rounds.
# [1]	train-rmse:21.85301	eval-rmse:21.68334
# [2]	train-rmse:16.18389	eval-rmse:16.32465
# [3]	train-rmse:12.19740	eval-rmse:12.79628
# [4]	train-rmse:9.09018	eval-rmse:10.16173
# [5]	train-rmse:6.96856	eval-rmse:8.64006
# [6]	train-rmse:5.33059	eval-rmse:7.79864
# [7]	train-rmse:4.31194	eval-rmse:7.42842
# [8]	train-rmse:3.45083	eval-rmse:7.07860
# [9]	train-rmse:2.88272	eval-rmse:6.90770
# [10]	train-rmse:2.53063	eval-rmse:6.82936
# [11]	train-rmse:2.09907	eval-rmse:6.76516
# [12]	train-rmse:1.86015	eval-rmse:6.65523
# [13]	train-rmse:1.47888	eval-rmse:6.55330
# [14]	train-rmse:1.20835	eval-rmse:6.42460
# [15]	train-rmse:1.05472	eval-rmse:6.38909
# [16]	train-rmse:0.93629	eval-rmse:6.35915
# [17]	train-rmse:0.82507	eval-rmse:6.32300
# [18]	train-rmse:0.76812	eval-rmse:6.30108
# [19]	train-rmse:0.71795	eval-rmse:6.30064
# [20]	train-rmse:0.63889	eval-rmse:6.29766
# [21]	train-rmse:0.55274	eval-rmse:6.28276
# [22]	train-rmse:0.47987	eval-rmse:6.24715
# [23]	train-rmse:0.43771	eval-rmse:6.24293
# [24]	train-rmse:0.39033	eval-rmse:6.23587
# [25]	train-rmse:0.36947	eval-rmse:6.21653
# [26]	train-rmse:0.32432	eval-rmse:6.19330
# [27]	train-rmse:0.28011	eval-rmse:6.19668
# [28]	train-rmse:0.23088	eval-rmse:6.17602
# [29]	train-rmse:0.19633	eval-rmse:6.16417
# [30]	train-rmse:0.17376	eval-rmse:6.16121
# [31]	train-rmse:0.14040	eval-rmse:6.15327
# [32]	train-rmse:0.11637	eval-rmse:6.15116
# [33]	train-rmse:0.10324	eval-rmse:6.14945
# [34]	train-rmse:0.09460	eval-rmse:6.14989
# [35]	train-rmse:0.08160	eval-rmse:6.14935
# [36]	train-rmse:0.07410	eval-rmse:6.14976
# [37]	train-rmse:0.06696	eval-rmse:6.15032
# [38]	train-rmse:0.05781	eval-rmse:6.14839
# [39]	train-rmse:0.05469	eval-rmse:6.14910
# [40]	train-rmse:0.04815	eval-rmse:6.15008
# [41]	train-rmse:0.04188	eval-rmse:6.14988
# [42]	train-rmse:0.03520	eval-rmse:6.14879
# [43]	train-rmse:0.03053	eval-rmse:6.14930
# [44]	train-rmse:0.02643	eval-rmse:6.14877
# [45]	train-rmse:0.02423	eval-rmse:6.14766
# [46]	train-rmse:0.02238	eval-rmse:6.14739
# [47]	train-rmse:0.02104	eval-rmse:6.14684
# [48]	train-rmse:0.01845	eval-rmse:6.14609
# [49]	train-rmse:0.01775	eval-rmse:6.14601
# [50]	train-rmse:0.01567	eval-rmse:6.14613
# [51]	train-rmse:0.01430	eval-rmse:6.14630
# [52]	train-rmse:0.01322	eval-rmse:6.14623
# [53]	train-rmse:0.01265	eval-rmse:6.14623
# [54]	train-rmse:0.01205	eval-rmse:6.14625
# [55]	train-rmse:0.01037	eval-rmse:6.14543
# [56]	train-rmse:0.00952	eval-rmse:6.14565
# [57]	train-rmse:0.00802	eval-rmse:6.14515
# [58]	train-rmse:0.00720	eval-rmse:6.14514
# [59]	train-rmse:0.00687	eval-rmse:6.14515
# [60]	train-rmse:0.00606	eval-rmse:6.14511
# [61]	train-rmse:0.00566	eval-rmse:6.14507
# [62]	train-rmse:0.00490	eval-rmse:6.14502
# [63]	train-rmse:0.00452	eval-rmse:6.14503
# [64]	train-rmse:0.00443	eval-rmse:6.14500
# [65]	train-rmse:0.00410	eval-rmse:6.14501
# [66]	train-rmse:0.00369	eval-rmse:6.14505
# [67]	train-rmse:0.00348	eval-rmse:6.14508
# [68]	train-rmse:0.00332	eval-rmse:6.14509
# [69]	train-rmse:0.00292	eval-rmse:6.14520
# [70]	train-rmse:0.00273	eval-rmse:6.14524
# [71]	train-rmse:0.00249	eval-rmse:6.14522
# [72]	train-rmse:0.00225	eval-rmse:6.14533
# [73]	train-rmse:0.00208	eval-rmse:6.14535
# [74]	train-rmse:0.00178	eval-rmse:6.14532
# [75]	train-rmse:0.00163	eval-rmse:6.14531
# [76]	train-rmse:0.00150	eval-rmse:6.14529
# [77]	train-rmse:0.00130	eval-rmse:6.14530
# [78]	train-rmse:0.00119	eval-rmse:6.14531
# [79]	train-rmse:0.00113	eval-rmse:6.14528
# [80]	train-rmse:0.00098	eval-rmse:6.14528
# [81]	train-rmse:0.00093	eval-rmse:6.14529
# [82]	train-rmse:0.00085	eval-rmse:6.14527
# [83]	train-rmse:0.00077	eval-rmse:6.14527
# [84]	train-rmse:0.00066	eval-rmse:6.14527
# Stopping. Best iteration:
# [64]	train-rmse:0.00443	eval-rmse:6.14500
#
# [02:06:10] WARNING: /Users/travis/build/dmlc/xgboost/src/objective/regression_obj.cu:170: reg:linear is now deprecated in favor of reg:squarederror.

# %%
import math
from sklearn.metrics import mean_squared_error

y_pred = bst.predict(dval)
mse = mean_squared_error(y_val, y_pred)
print('RMSE:', math.sqrt(mse))
# Out:
# RMSE: 6.1452692282488774

# %%
train_metric = evals_result['train']['rmse']
plt.plot(train_metric, label='train rmse')

eval_metric = evals_result['eval']['rmse']
plt.plot(eval_metric, label='eval rmse')

plt.grid()
plt.legend()
plt.xlabel('rounds')
plt.ylabel('rmse')
plt.show()

# %%
_, ax = plt.subplots(figsize=(12, 8))

xgb.plot_importance(bst,ax=ax,
                    importance_type='gain',
                    show_values=True,
                    color='red')

plt.yticks(fontsize=12)
#plt.figure(dpi=80)

plt.show()

# %%
#xgb.to_graphviz(bst, num_trees=1)

# %%
df_test = laod_data('ranking_test_data.csv')
print(len(df_test))
#df_test.head(3)
# Out:
# 65

# %%
df_test2 = data_preprocess(df_test)
df_test2.head(3)
# Out:
#    category    created_at    updated_at  char_count_sum  new_line_count_sum  \
# 0         6  1.585469e+09  1.593763e+09           37740                2310
# 1         6  1.591009e+09  1.593774e+09          144330                5760
# 2         6  1.587737e+09  1.593006e+09          156720                6210
#
#    talk_char_count_sum  new_line_count_rate_sum  talk_char_count_rate_sum  \
# 0                    0                 0.061208                  0.000000
# 1                44100                 0.039909                  0.305550
# 2                13290                 0.039625                  0.084801
#
#    char_count_avg  new_line_count_avg  ...  wc_rate_4  wc_rate_5  wc_rate_6  \
# 0          1258.0                77.0  ...   0.240634   0.149856   0.386167
# 1          4811.0               192.0  ...   0.252519   0.217420   0.238219
# 2          5224.0               207.0  ...   0.248532   0.211128   0.241731
#
#    wc_rate_7  wc_rate_8  wc_rate_9  wc_rate_10  wc_rate_11  wc_rate_12  rating
# 0   0.014409   0.000000   0.000000    0.000000    0.171470    0.001441     -10
# 1   0.019175   0.002600   0.006175    0.000975    0.132272    0.008450     -10
# 2   0.011437   0.002473   0.007419    0.001546    0.126739    0.012056     -10
#
# [3 rows x 27 columns]

# %%
X = df_test2.drop(['rating'], axis=1).values
y = df_test2['rating'].values
print(X.shape)

#dtrain = xgb.DMatrix(X_train, label=y_train)
dtest = xgb.DMatrix(X, label=y, feature_names=feature_names)
#print(dtest)
# Out:
# (65, 26)

# %%
y_pred = bst.predict(dtest)
#y_pred

# %%
df_rating = pd.DataFrame(columns=['ncode', 'title', 'rating'])

for i, y in enumerate(y_pred):
    row = df_test.loc[i] 
    #print('{}\t{}\t{}'.format(row.ncode, row.title, y))
    df_rating = df_rating.append({'ncode': row.ncode, 'title': row.title, 'rating': y}, ignore_index=True)

# %%
#df_rating.head()

# %%
df_rating.describe()
# Out:
#           rating
# count  65.000000
# mean   27.098251
# std    10.864998
# min     1.719725
# 25%    19.784328
# 50%    28.296804
# 75%    34.555244
# max    67.191559

# %%
df_rating.var()
# Out:
# rating    118.04819
# dtype: float64

# %%
df_rating.median()
# Out:
# rating    28.296804
# dtype: float64

# %%
pd.set_option('display.max_rows', None)

df_rating.sort_values('rating', ascending=False)
# Out:
#       ncode                                              title     rating
# 60  n5645ci                                      自分が異世界に転移するなら  67.191559
# 61  n4344dy                                世界最強の後衛　～迷宮国の新人探索者～  43.134911
# 0   n8642gc                                       聖貨を集めて、ぶん回せ！  42.195637
# 11  n1217et                   信者ゼロの女神サマと始める異世界攻略　クラスメイト最弱の魔法使い  41.357407
# 64  n3258fh                          クラスメイトに殺された時、僕の復讐は大体達成された  40.276642
# 30  n1290ff            最強陰陽師の異世界転生記　～下僕の妖怪どもに比べてモンスターが弱すぎるんだが～  40.187992
# 50  n5981bn                           ニートだけどハロワにいったら異世界につれてかれた  39.938343
# 10  n1773gf           16年間魔法が使えず落ちこぼれだった俺が、科学者だった前世を思い出して異世界無双  37.709740
# 44  n9984fb                             身体は児童、中身はおっさんの成り上がり冒険記  37.640198
# 38  n3742ey                                   ご主人様とゆく異世界サバイバル！  37.638432
# 35  n4444ge  植物モンスター娘日記　〜聖女だった私が裏切られた果てにアルラウネに転生してしまったので、これ...  37.111443
# 18  n2276dz                                    異世界でスローライフを（願望）  36.714233
# 4   n6812gh         悪徳領主の息子に転生！？　～普通に行動しているだけなのに、周囲からちやほやされます～  36.257275
# 8   n0512gh  『錬金BOX』で生産チート+付与無双～無能と罵られ侯爵家を追放されたが、なんでも錬成できる箱...  36.061481
# 58  n2671do                        魔王になったので、ダンジョン造って人外娘とほのぼのする  35.233490
# 12  n7657bb                                          かわいいコックさん  34.790810
# 32  n4546fc                異世界の貧乏農家に転生したので、レンガを作って城を建てることにしました  34.555244
# 53  n5782dy                                ハズレ判定から始まったチート魔術士生活  34.397377
# 49  n1234gg      魔法戦士セイクリッド・ナイツ～エロゲの触手怪人に転生した俺は、変身ヒロインたちを守り抜く～  33.940369
# 21  n8106fu                                      異世界のんびり素材採取生活  33.577511
# 43  n0350em                                        異世界転移、地雷付き。  33.271038
# 20  n0610eg                       魔石グルメ　～魔物の力を食べたオレは最強！～（Web版）  32.644375
# 63  n6078gg               イントゥ・ザ・ゴーレム！～土くれに生まれ変わった私は自己改造で進化する～  31.689842
# 19  n6475db                                  私、能力は平均値でって言ったよね！  30.968798
# 37  n3726bt                                              レジェンド  30.907759
# 23  n9629ex                               最弱テイマーはゴミ拾いの旅を始めました。  30.737247
# 52  n6247cr                                      鑑定能力で調合師になります  30.317293
# 42  n0229fv    植物魔法チートでのんびり領主生活始めます～前世の知識を駆使して農業したら、逆転人生始まった件～  29.336798
# 59  n4698cv                          転生したらドラゴンの卵だった～最強以外目指さねぇ～  29.057673
# 24  n8568fy        普通職の異世界スローライフ　～チート（があるくせに小者）な薬剤師の無双（しない）物語～  28.770821
# 55  n3406ek                                   異世界で土地を買って農場を作ろう  28.755014
# 16  n1118fh                                        加護なし令嬢の小さな村  28.553453
# 6   n0121gf  異世界へ来たのはいいけれど、モンスターと戦える程若くないおっさん。神様からもらったスキルは戦...  28.296804
# 13  n5677cl                           亡びの国の征服者～魔王は世界を征服するようです～  26.961802
# 54  n1444fs      転生領主の優良開拓〜前世の記憶を生かしてホワイトに努めたら、有能な人材が集まりすぎました〜  26.569580
# 28  n1970fg                                          田中家、転生する。  26.529125
# 41  n6078fg      不死鳥への転生　ドラゴン倒せるって普通の鳥じゃないよね？　（旧題：憧れへの転生　以下同文）  26.387390
# 51  n4499gh                                      よいこの世界統一せんそう！  26.028296
# 47  n9940gd                                      最強錬金術師の異世界珍道中  24.618288
# 46  n6829bd                                        賢者の弟子を名乗る賢者  23.200024
# 48  n9293gf           ゲームのストーリー開始前に死ぬ“設定上最強キャラ”に転生したので頑張って生きたい  22.615269
# 26  n5529cy                              老後に備えて異世界で８万枚の金貨を貯めます  21.351095
# 39  n6006cw                                          転生したら剣でした  21.197262
# 45  n1745ct                                       四度目は嫌な死属性魔術師  21.163723
# 17  n3191eh                                  乙女ゲー世界はモブに厳しい世界です  20.689278
# 57  n8760ei                        異世界黙示録マイノグーラ～破滅の文明で始める世界征服～  20.320898
# 3   n8604ge      スキル「屋台」で異世界生活～食料生成スキルを手に入れたので、商会を立ち上げようと思います～  20.247860
# 7   n4834fx             転生先が残念王子だった件　～今は腹筋１回もできないけど痩せて異世界救います～  19.958874
# 34  n4185ci                                        くま　クマ　熊　ベアー  19.784328
# 40  n2421eu                                        転生幼女はあきらめない  19.407711
# 31  n4342ge  聖女に追放された転生公爵は、辺境でのんびりと畑を耕すつもりだった～来るなというのに領民が沢山...  19.115587
# 27  n9544br                                              週末冒険者  18.773207
# 1   n8693gg                           十年目、帰還を諦めた転移者はいまさら主人公になる  18.097172
# 5   n7408gf                                         異世界ゆるり農家生活  17.774675
# 22  n4811fg             ＴＲＰＧプレイヤーが異世界で最強ビルドを目指す 　～ヘンダーソン氏の福音を～  16.865213
# 2   n4452ge                            俺だけレベルが上がる世界で悪徳領主になっていた  14.875877
# 15  n2945eg                                     アラフォー男の異世界通販生活  14.849195
# 25  n3245fy                                           主人公じゃない！  13.842650
# 36  n6088cy                                    ポーション頼みで生き延びます！  12.885015
# 9   n4205gg               かませ犬から始める天下統一〜前世のアニメの第一部のボスに憑依してました〜  12.298311
# 29  n8516fu                  劣等人の魔剣使い　スキルボードを駆使して最強に至る（WEB連載版）  12.049829
# 14  n5375cy                                転生して田舎でスローライフをおくりたい  11.860207
# 33  n6300fz               領民0の土地を押し付けられた俺、生産スキルを駆使して最強国家を作り上げる   8.278570
# 56  n7080gh                                 連載版　踏み台が己を自覚した結果ww   7.853288
# 62  n7056gh  レベルが上がらない！　～と思ってたら元の世界に帰って悪党ぶん殴ってザクザクレベルアップ。異世...   1.719725
